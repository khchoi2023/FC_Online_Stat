# %%
import pandas as pd
import random
import os
import re
import numpy as np
from pycaret.regression import *
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

pd.options.display.max_columns = None
# pd.options.display.max_rows = None


def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %%
df = pd.read_csv('gk-data.csv', encoding='cp949')
df
# Out:
#          name position  강화  max  min  only_one   출생   리그    생년  생월  생일    키  \
# 0         이운재       GK   1    0    1         0   한국   한국  1973   4  26  182
# 1         이운재       GK   1    1    0         0   한국   한국  1973   4  26  182
# 2         김병지       GK   1    0    1         0   한국   한국  1970   4   8  184
# 3         김병지       GK   1    1    0         0   한국   한국  1970   4   8  184
# 4         조현우       GK   1    0    1         0   한국   한국  1991   9  25  189
# ..        ...      ...  ..  ...  ...       ...  ...  ...   ...  ..  ..  ...
# 98      A. 사빈       GK   1    0    0         1  러시아  러시아  1999   8  30  193
# 99     A. 바슈틴       GK   1    1    0         0  러시아  스웨덴  1995   3   4  190
# 100    A. 바슈틴       GK   1    0    1         0  러시아  스웨덴  1995   3   4  190
# 101  A. 미트류스킨       GK   1    0    0         1  러시아  러시아  1996   2   8  189
# 102   A. 레브로프       GK   1    0    0         1  러시아  러시아  1984   3   4  193
#
#      몸무게  체격    명성  능력치  다이빙  핸들링   킥  반응속도  스피드  위치선정
# 0     82  보통  유명선수   89   86   92  89    93   39    93
# 1     82  보통  유명선수  104  102  109  96   105   57   108
# 2     78  보통  유명선수   89   92   89  88    89   61    93
# 3     78  보통  유명선수   97  101   97  96    97   59   101
# 4     75  마름  일반선수   84   85   81  69    92   61    86
# ..   ...  ..   ...  ...  ...  ...  ..   ...  ...   ...
# 98    94  보통  일반선수   55   60   56  57    59   25    52
# 99    80  보통  일반선수   63   66   58  61    67   35    62
# 100   80  보통  일반선수   61   64   57  60    65   35    61
# 101   79  보통  일반선수   59   63   56  61    60   35    63
# 102   90  보통  일반선수   63   63   61  59    63   32    68
#
# [103 rows x 22 columns]

# %%
sa = pd.read_csv('result4.csv', encoding='cp949')
sa
# Out:
#    name position  강화  max  min  only_one   출생  리그    생년  생월  생일    키  몸무게  체격  \
# 0  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 1  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
# 2  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 3  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
#
#      명성     능력치        다이빙        핸들링          킥
# 0  일반선수  70.335  69.450220  71.648570  67.132981
# 1  일반선수  78.240  77.514300  79.796875  74.112222
# 2  유명선수  71.895  71.041600  73.256584  68.510283
# 3  유명선수  79.250  78.544624  80.837960  75.003941

# %%
# 특정 칼럼만 추출해서 새로운 데이터프레임 생성
selected_columns = ['name', 'position', '강화', 'max', 'min', 'only_one', '출생', '리그',
                    '생년', '생월', '생일', '키', '몸무게', '체격', '명성', '능력치',
                    '다이빙', '핸들링', '킥', '반응속도']

df2 = df[selected_columns]
df2
# Out:
#          name position  강화  max  min  only_one   출생   리그    생년  생월  생일    키  \
# 0         이운재       GK   1    0    1         0   한국   한국  1973   4  26  182
# 1         이운재       GK   1    1    0         0   한국   한국  1973   4  26  182
# 2         김병지       GK   1    0    1         0   한국   한국  1970   4   8  184
# 3         김병지       GK   1    1    0         0   한국   한국  1970   4   8  184
# 4         조현우       GK   1    0    1         0   한국   한국  1991   9  25  189
# ..        ...      ...  ..  ...  ...       ...  ...  ...   ...  ..  ..  ...
# 98      A. 사빈       GK   1    0    0         1  러시아  러시아  1999   8  30  193
# 99     A. 바슈틴       GK   1    1    0         0  러시아  스웨덴  1995   3   4  190
# 100    A. 바슈틴       GK   1    0    1         0  러시아  스웨덴  1995   3   4  190
# 101  A. 미트류스킨       GK   1    0    0         1  러시아  러시아  1996   2   8  189
# 102   A. 레브로프       GK   1    0    0         1  러시아  러시아  1984   3   4  193
#
#      몸무게  체격    명성  능력치  다이빙  핸들링   킥  반응속도
# 0     82  보통  유명선수   89   86   92  89    93
# 1     82  보통  유명선수  104  102  109  96   105
# 2     78  보통  유명선수   89   92   89  88    89
# 3     78  보통  유명선수   97  101   97  96    97
# 4     75  마름  일반선수   84   85   81  69    92
# ..   ...  ..   ...  ...  ...  ...  ..   ...
# 98    94  보통  일반선수   55   60   56  57    59
# 99    80  보통  일반선수   63   66   58  61    67
# 100   80  보통  일반선수   61   64   57  60    65
# 101   79  보통  일반선수   59   63   56  61    60
# 102   90  보통  일반선수   63   63   61  59    63
#
# [103 rows x 20 columns]

# %%
# X = df2.drop(['능력치'], axis = 1)
# y = df2['능력치']
# X = df2.drop(['다이빙'], axis = 1)
# y = df2['다이빙']
# X = df2.drop(['핸들링'], axis = 1)
# y = df2['핸들링']
# X = df2.drop(['킥'], axis = 1)
# y = df2['킥']
X = df2.drop(['반응속도'], axis = 1)
y = df2['반응속도']



# 데이터 셋을 셔플하지 않고 train/test로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %% [markdown]
# # Pycaret

# %%
# 분류 작업을 위한 pycaret 초기화
clf = setup(X_train, target=y_train, session_id=123)
# Out:
# <style type="text/css">
# #T_8114c_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8114c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8114c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8114c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8114c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8114c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8114c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8114c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8114c_row1_col1" class="data row1 col1" >반응속도</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8114c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8114c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8114c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8114c_row3_col1" class="data row3 col1" >(82, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8114c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8114c_row4_col1" class="data row4 col1" >(82, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8114c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8114c_row5_col1" class="data row5 col1" >(57, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8114c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8114c_row6_col1" class="data row6 col1" >(25, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8114c_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_8114c_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8114c_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_8114c_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8114c_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_8114c_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8114c_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_8114c_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8114c_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_8114c_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8114c_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_8114c_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8114c_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_8114c_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8114c_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_8114c_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8114c_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_8114c_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8114c_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_8114c_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8114c_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_8114c_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8114c_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_8114c_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8114c_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_8114c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8114c_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_8114c_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8114c_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_8114c_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8114c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8114c_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_8114c_row22_col1" class="data row22 col1" >111d</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(n_select = 3)

# 특정 모델들만 비교 (예: LightGBM, XGBoost, Random Forest)
# best_model = compare_models(n_select = 3, include=['huber', 'dummy', 'en', 'knn', 'lasso', 'ada', 'lightgbm', 'catboost', 'lightgbm', 'xgboost'])
# Out:
# <style type="text/css">
# #T_40507 th {
#   text-align: left;
# }
# #T_40507_row0_col0, #T_40507_row0_col1, #T_40507_row0_col2, #T_40507_row0_col3, #T_40507_row0_col6, #T_40507_row1_col0, #T_40507_row2_col0, #T_40507_row2_col1, #T_40507_row2_col2, #T_40507_row2_col3, #T_40507_row2_col4, #T_40507_row2_col5, #T_40507_row2_col6, #T_40507_row3_col0, #T_40507_row3_col1, #T_40507_row3_col2, #T_40507_row3_col3, #T_40507_row3_col4, #T_40507_row3_col5, #T_40507_row3_col6, #T_40507_row4_col0, #T_40507_row4_col1, #T_40507_row4_col2, #T_40507_row4_col3, #T_40507_row4_col4, #T_40507_row4_col5, #T_40507_row4_col6, #T_40507_row5_col0, #T_40507_row5_col1, #T_40507_row5_col2, #T_40507_row5_col3, #T_40507_row5_col4, #T_40507_row5_col5, #T_40507_row5_col6, #T_40507_row6_col0, #T_40507_row6_col1, #T_40507_row6_col2, #T_40507_row6_col3, #T_40507_row6_col4, #T_40507_row6_col5, #T_40507_row6_col6, #T_40507_row7_col0, #T_40507_row7_col1, #T_40507_row7_col2, #T_40507_row7_col3, #T_40507_row7_col4, #T_40507_row7_col5, #T_40507_row7_col6, #T_40507_row8_col0, #T_40507_row8_col1, #T_40507_row8_col2, #T_40507_row8_col3, #T_40507_row8_col4, #T_40507_row8_col5, #T_40507_row8_col6, #T_40507_row9_col0, #T_40507_row9_col1, #T_40507_row9_col2, #T_40507_row9_col3, #T_40507_row9_col4, #T_40507_row9_col5, #T_40507_row9_col6, #T_40507_row10_col0, #T_40507_row10_col1, #T_40507_row10_col2, #T_40507_row10_col3, #T_40507_row10_col4, #T_40507_row10_col5, #T_40507_row10_col6, #T_40507_row11_col0, #T_40507_row11_col1, #T_40507_row11_col2, #T_40507_row11_col3, #T_40507_row11_col4, #T_40507_row11_col5, #T_40507_row11_col6, #T_40507_row12_col0, #T_40507_row12_col1, #T_40507_row12_col2, #T_40507_row12_col3, #T_40507_row12_col4, #T_40507_row12_col5, #T_40507_row12_col6, #T_40507_row13_col0, #T_40507_row13_col1, #T_40507_row13_col2, #T_40507_row13_col3, #T_40507_row13_col4, #T_40507_row13_col5, #T_40507_row13_col6, #T_40507_row14_col0, #T_40507_row14_col1, #T_40507_row14_col2, #T_40507_row14_col3, #T_40507_row14_col4, #T_40507_row14_col5, #T_40507_row14_col6, #T_40507_row15_col0, #T_40507_row15_col1, #T_40507_row15_col2, #T_40507_row15_col3, #T_40507_row15_col4, #T_40507_row15_col5, #T_40507_row15_col6, #T_40507_row16_col0, #T_40507_row16_col1, #T_40507_row16_col2, #T_40507_row16_col3, #T_40507_row16_col4, #T_40507_row16_col5, #T_40507_row16_col6, #T_40507_row17_col0, #T_40507_row17_col1, #T_40507_row17_col2, #T_40507_row17_col3, #T_40507_row17_col4, #T_40507_row17_col5, #T_40507_row17_col6 {
#   text-align: left;
# }
# #T_40507_row0_col4, #T_40507_row0_col5, #T_40507_row1_col1, #T_40507_row1_col2, #T_40507_row1_col3, #T_40507_row1_col4, #T_40507_row1_col5, #T_40507_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_40507_row0_col7, #T_40507_row1_col7, #T_40507_row2_col7, #T_40507_row3_col7, #T_40507_row4_col7, #T_40507_row5_col7, #T_40507_row6_col7, #T_40507_row7_col7, #T_40507_row8_col7, #T_40507_row9_col7, #T_40507_row10_col7, #T_40507_row11_col7, #T_40507_row12_col7, #T_40507_row13_col7, #T_40507_row14_col7, #T_40507_row15_col7, #T_40507_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_40507_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_40507">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40507_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_40507_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_40507_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_40507_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_40507_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_40507_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_40507_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_40507_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40507_level0_row0" class="row_heading level0 row0" >lasso</th>
#       <td id="T_40507_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_40507_row0_col1" class="data row0 col1" >1.9487</td>
#       <td id="T_40507_row0_col2" class="data row0 col2" >5.2765</td>
#       <td id="T_40507_row0_col3" class="data row0 col3" >2.2347</td>
#       <td id="T_40507_row0_col4" class="data row0 col4" >0.9677</td>
#       <td id="T_40507_row0_col5" class="data row0 col5" >0.0300</td>
#       <td id="T_40507_row0_col6" class="data row0 col6" >0.0260</td>
#       <td id="T_40507_row0_col7" class="data row0 col7" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_40507_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_40507_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_40507_row1_col1" class="data row1 col1" >1.9480</td>
#       <td id="T_40507_row1_col2" class="data row1 col2" >5.2710</td>
#       <td id="T_40507_row1_col3" class="data row1 col3" >2.2336</td>
#       <td id="T_40507_row1_col4" class="data row1 col4" >0.9677</td>
#       <td id="T_40507_row1_col5" class="data row1 col5" >0.0300</td>
#       <td id="T_40507_row1_col6" class="data row1 col6" >0.0259</td>
#       <td id="T_40507_row1_col7" class="data row1 col7" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_40507_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_40507_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_40507_row2_col1" class="data row2 col1" >2.0201</td>
#       <td id="T_40507_row2_col2" class="data row2 col2" >5.7247</td>
#       <td id="T_40507_row2_col3" class="data row2 col3" >2.3493</td>
#       <td id="T_40507_row2_col4" class="data row2 col4" >0.9650</td>
#       <td id="T_40507_row2_col5" class="data row2 col5" >0.0315</td>
#       <td id="T_40507_row2_col6" class="data row2 col6" >0.0268</td>
#       <td id="T_40507_row2_col7" class="data row2 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_40507_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_40507_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_40507_row3_col1" class="data row3 col1" >2.1998</td>
#       <td id="T_40507_row3_col2" class="data row3 col2" >6.8201</td>
#       <td id="T_40507_row3_col3" class="data row3 col3" >2.5656</td>
#       <td id="T_40507_row3_col4" class="data row3 col4" >0.9565</td>
#       <td id="T_40507_row3_col5" class="data row3 col5" >0.0351</td>
#       <td id="T_40507_row3_col6" class="data row3 col6" >0.0294</td>
#       <td id="T_40507_row3_col7" class="data row3 col7" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_40507_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_40507_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_40507_row4_col1" class="data row4 col1" >2.2423</td>
#       <td id="T_40507_row4_col2" class="data row4 col2" >7.2916</td>
#       <td id="T_40507_row4_col3" class="data row4 col3" >2.6847</td>
#       <td id="T_40507_row4_col4" class="data row4 col4" >0.9547</td>
#       <td id="T_40507_row4_col5" class="data row4 col5" >0.0373</td>
#       <td id="T_40507_row4_col6" class="data row4 col6" >0.0303</td>
#       <td id="T_40507_row4_col7" class="data row4 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_40507_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_40507_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_40507_row5_col1" class="data row5 col1" >2.6800</td>
#       <td id="T_40507_row5_col2" class="data row5 col2" >12.5554</td>
#       <td id="T_40507_row5_col3" class="data row5 col3" >3.3096</td>
#       <td id="T_40507_row5_col4" class="data row5 col4" >0.9386</td>
#       <td id="T_40507_row5_col5" class="data row5 col5" >0.0461</td>
#       <td id="T_40507_row5_col6" class="data row5 col6" >0.0379</td>
#       <td id="T_40507_row5_col7" class="data row5 col7" >0.0600</td>
#     </tr>
#     <tr>
#       <th id="T_40507_level0_row6" class="row_heading level0 row6" >g

# %%
b1 = best_model[0]
b2 = best_model[1]
b3 = best_model[2]

predictions_1 = predict_model(b1,data=X_test)
predictions_2 = predict_model(b2,data=X_test)
predictions_3 = predict_model(b3,data=X_test)

# %%
# b1
b2
# Out:
# LassoLars(random_state=123)

# %%
# predictions_1
predictions_2
# Out:
#           name position  강화  max  min  only_one   출생    리그    생년  생월  생일    키  \
# 30         노동건       GK   1    0    0         1   한국    한국  1991  10   4  192
# 67     E. 코보제프       GK   1    0    0         1  러시아   러시아  1990   1  11  188
# 62   이고리 아킨페예프       GK   1    1    0         0  러시아   러시아  1986   4   8  186
# 47         윤평국       GK   1    1    0         0   한국    한국  1992   2   8  189
# 42         오승훈       GK   1    1    0         0   한국    한국  1988   6  30  192
# 40         양형모       GK   1    1    0         0   한국    한국  1991   7  16  185
# 90     I. 스비노프       GK   1    0    0         1  러시아   러시아  2000   9  25  190
# 45         유상훈       GK   1    0    1         0   한국    한국  1989   5  25  194
# 10         김영광       GK   1    1    0         0   한국    한국  1983   6  28  184
# 0          이운재       GK   1    0    1         0   한국    한국  1973   4  26  182
# 18         구성윤       GK   1    1    0         0   한국    한국  1994   6  27  195
# 31         박주원       GK   1    0    0         1   한국    한국  1990  10  19  191
# 97     A. 셀리호프       GK   1    0    0         1  러시아   러시아  1994   4   7  190
# 85     S. 크리추크       GK   1    0    1         0  러시아  포르투갈  1990  12   1  192
# 76     막심 루다코프       GK   1    0    0         1  러시아   핀란드  1996   1  22  190
# 4          조현우       GK   1    0    1         0   한국    한국  1991   9  25  189
# 79        길레르미       GK   1    0    0         1  러시아   러시아  1985  12  12  198
# 33         백종범       GK   1    0    0         1   한국    한국  2001   1  21  190
# 12         최은성       GK   1    0    1         0   한국    한국  1971   4   5  184
# 26         김정훈       GK   1    0    1         0   한국    한국  2001   4  20  188
# 100     A. 바슈틴       GK   1    0    1         0  러시아   스웨덴  1995   3   4  190
#
#      몸무게  체격    명성  능력치  다이빙  핸들링    킥  prediction_label
# 30    88  보통  일반선수   87   94   84   77         89.835997
# 67    81  보통  일반선수   60   66   57   60         63.997869
# 62    78  보통  유명선수  101  105   92  100        103.484554
# 47    85  보통  일반선수   85   85   89   76         87.069983
# 42    79  보통  일반선수   87   91   85   84         90.477087
# 40    84  보통  일반선수  101  106  100   93        104.088559
# 90    81  마름  일반선수   57   59   59   57         60.914635
# 45    84  보통  일반선수   82   82   83   76         84.582722
# 10    86  보통  일반선수   94   89   94   85         96.158446
# 0     82  보통  유명선수   89   86   92   89         91.661226
# 18    82  마름  일반선수   89   91   87   84         91.762313
# 31    77  보통  일반선수   85   87   87   77         87.769318
# 97    85  보통  일반선수   64   66   62   63         66.900291
# 85    85  보통  일반선수   64   65   67   65         66.322789
# 76    79  마름  일반선수   58   61   55   57         61.915030
# 4     75  마름  일반선수   84   85   81   69         87.026350
# 79    96  마름  유명선수   70   74   66   67         72.757586
# 33    85  보통  일반선수   81   86   80   75         84.573555
# 12    82  보통  일반선수   83   84   81   77         85.443506
# 26    80  보통  일반선수   82   81   83   76         84.603595
# 100   80  보통  일반선수   61   64   57   60         64.024386

# %%
# 인덱스를 기준으로 레프트 조인 수행
# result = predictions_1.join(y_test, how='left')
result = predictions_2.join(y_test, how='left')
result
# Out:
#           name position  강화  max  min  only_one   출생    리그    생년  생월  ...  \
# 30         노동건       GK   1    0    0         1   한국    한국  1991  10  ...
# 67     E. 코보제프       GK   1    0    0         1  러시아   러시아  1990   1  ...
# 62   이고리 아킨페예프       GK   1    1    0         0  러시아   러시아  1986   4  ...
# 47         윤평국       GK   1    1    0         0   한국    한국  1992   2  ...
# 42         오승훈       GK   1    1    0         0   한국    한국  1988   6  ...
# 40         양형모       GK   1    1    0         0   한국    한국  1991   7  ...
# 90     I. 스비노프       GK   1    0    0         1  러시아   러시아  2000   9  ...
# 45         유상훈       GK   1    0    1         0   한국    한국  1989   5  ...
# 10         김영광       GK   1    1    0         0   한국    한국  1983   6  ...
# 0          이운재       GK   1    0    1         0   한국    한국  1973   4  ...
# 18         구성윤       GK   1    1    0         0   한국    한국  1994   6  ...
# 31         박주원       GK   1    0    0         1   한국    한국  1990  10  ...
# 97     A. 셀리호프       GK   1    0    0         1  러시아   러시아  1994   4  ...
# 85     S. 크리추크       GK   1    0    1         0  러시아  포르투갈  1990  12  ...
# 76     막심 루다코프       GK   1    0    0         1  러시아   핀란드  1996   1  ...
# 4          조현우       GK   1    0    1         0   한국    한국  1991   9  ...
# 79        길레르미       GK   1    0    0         1  러시아   러시아  1985  12  ...
# 33         백종범       GK   1    0    0         1   한국    한국  2001   1  ...
# 12         최은성       GK   1    0    1         0   한국    한국  1971   4  ...
# 26         김정훈       GK   1    0    1         0   한국    한국  2001   4  ...
# 100     A. 바슈틴       GK   1    0    1         0  러시아   스웨덴  1995   3  ...
#
#        키  몸무게  체격    명성  능력치  다이빙  핸들링    킥  prediction_label  반응속도
# 30   192   88  보통  일반선수   87   94   84   77         89.835997    91
# 67   188   81  보통  일반선수   60   66   57   60         63.997869    65
# 62   186   78  보통  유명선수  101  105   92  100        103.484554   107
# 47   189   85  보통  일반선수   85   85   89   76         87.069983    88
# 42   192   79  보통  일반선수   87   91   85   84         90.477087    90
# 40   185   84  보통  일반선수  101  106  100   93        104.088559   102
# 90   190   81  마름  일반선수   57   59   59   57         60.914635    60
# 45   194   84  보통  일반선수   82   82   83   76         84.582722    87
# 10   184   86  보통  일반선수   94   89   94   85         96.158446    99
# 0    182   82  보통  유명선수   89   86   92   89         91.661226    93
# 18   195   82  마름  일반선수   89   91   87   84         91.762313    91
# 31   191   77  보통  일반선수   85   87   87   77         87.769318    87
# 97   190   85  보통  일반선수   64   66   62   63         66.900291    70
# 85   192   85  보통  일반선수   64   65   67   65         66.322789    63
# 76   190   79  마름  일반선수   58   61   55   57         61.915030    63
# 4    189   75  마름  일반선수   84   85   81   69         87.026350    92
# 79   198   96  마름  유명선수   70   74   66   67         72.757586    73
# 33   190   85  보통  일반선수   81   86   80   75         84.573555    89
# 12   184   82  보통  일반선수   83   84   81   77         85.443506    87
# 26   188   80  보통  일반선수   82   81   83   76         84.603595    88
# 100  190   80  보통  일반선수   61   64   57   60         64.024386    65
#
# [21 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(result.index, result['prediction_label'], color='red', alpha=0.5, label='Prediction Label')
plt.scatter(result.index, result['반응속도'], color='blue', alpha=0.5, label='Y')

plt.title('Prediction vs Y')
plt.xlabel('Index')
plt.ylabel('Value')

legend = plt.legend(frameon=True)
legend.get_frame().set_edgecolor('black')
legend.get_frame().set_linewidth(1.5)
    
plt.grid(True)
plt.show()

# %%
# sa1 = predict_model(b1,data=sa)
sa1 = predict_model(b2,data=sa)
sa1
# Out:
#    name position  강화  max  min  only_one   출생  리그    생년  생월  생일    키  몸무게  체격  \
# 0  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 1  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
# 2  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 3  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
#
#      명성        능력치        다이빙        핸들링          킥  prediction_label
# 0  일반선수  70.334999  69.450218  71.648567  67.132980         72.518331
# 1  일반선수  78.239998  77.514297  79.796875  74.112221         80.227217
# 2  유명선수  71.894997  71.041603  73.256584  68.510284         74.039626
# 3  유명선수  79.250000  78.544624  80.837959  75.003944         81.212162

# %%
# sa1['prediction_label'] = sa1['prediction_label'].round()
# sa1.rename(columns={'prediction_label': '능력치'}, inplace=True)
# sa1.rename(columns={'prediction_label': '다이빙'}, inplace=True)
# sa1.rename(columns={'prediction_label': '핸들링'}, inplace=True)
# sa1.rename(columns={'prediction_label': '킥'}, inplace=True)
sa1.rename(columns={'prediction_label': '반응속도'}, inplace=True)
sa1
# Out:
#    name position  강화  max  min  only_one   출생  리그    생년  생월  생일    키  몸무게  체격  \
# 0  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 1  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
# 2  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 3  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
#
#      명성        능력치        다이빙        핸들링          킥       반응속도
# 0  일반선수  70.334999  69.450218  71.648567  67.132980  72.518331
# 1  일반선수  78.239998  77.514297  79.796875  74.112221  80.227217
# 2  유명선수  71.894997  71.041603  73.256584  68.510284  74.039626
# 3  유명선수  79.250000  78.544624  80.837959  75.003944  81.212162

# %%
# sa1.to_csv('result1.csv', index=False, encoding='cp949')
# sa1.to_csv('result2.csv', index=False, encoding='cp949')
# sa1.to_csv('result3.csv', index=False, encoding='cp949')
# sa1.to_csv('result4.csv', index=False, encoding='cp949')
sa1.to_csv('result5.csv', index=False, encoding='cp949')
print("done")
# Out:
# done
