# %%
import pandas as pd
import random
import os
import re
import numpy as np
from pycaret.regression import *
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

pd.options.display.max_columns = None
# pd.options.display.max_rows = None


def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %%
df = pd.read_csv('gk-data.csv', encoding='cp949')
df
# Out:
#          name position  강화  max  min  only_one   출생   리그    생년  생월  생일    키  \
# 0         이운재       GK   1    0    1         0   한국   한국  1973   4  26  182
# 1         이운재       GK   1    1    0         0   한국   한국  1973   4  26  182
# 2         김병지       GK   1    0    1         0   한국   한국  1970   4   8  184
# 3         김병지       GK   1    1    0         0   한국   한국  1970   4   8  184
# 4         조현우       GK   1    0    1         0   한국   한국  1991   9  25  189
# ..        ...      ...  ..  ...  ...       ...  ...  ...   ...  ..  ..  ...
# 98      A. 사빈       GK   1    0    0         1  러시아  러시아  1999   8  30  193
# 99     A. 바슈틴       GK   1    1    0         0  러시아  스웨덴  1995   3   4  190
# 100    A. 바슈틴       GK   1    0    1         0  러시아  스웨덴  1995   3   4  190
# 101  A. 미트류스킨       GK   1    0    0         1  러시아  러시아  1996   2   8  189
# 102   A. 레브로프       GK   1    0    0         1  러시아  러시아  1984   3   4  193
#
#      몸무게  체격    명성  능력치  다이빙  핸들링   킥  반응속도  스피드  위치선정
# 0     82  보통  유명선수   89   86   92  89    93   39    93
# 1     82  보통  유명선수  104  102  109  96   105   57   108
# 2     78  보통  유명선수   89   92   89  88    89   61    93
# 3     78  보통  유명선수   97  101   97  96    97   59   101
# 4     75  마름  일반선수   84   85   81  69    92   61    86
# ..   ...  ..   ...  ...  ...  ...  ..   ...  ...   ...
# 98    94  보통  일반선수   55   60   56  57    59   25    52
# 99    80  보통  일반선수   63   66   58  61    67   35    62
# 100   80  보통  일반선수   61   64   57  60    65   35    61
# 101   79  보통  일반선수   59   63   56  61    60   35    63
# 102   90  보통  일반선수   63   63   61  59    63   32    68
#
# [103 rows x 22 columns]

# %%
sa = pd.read_csv('result2.csv', encoding='cp949')
sa
# Out:
#    name position  강화  max  min  only_one   출생  리그    생년  생월  생일    키  몸무게  체격  \
# 0  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 1  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
# 2  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 3  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
#
#      명성     능력치        다이빙
# 0  일반선수  70.335  69.450215
# 1  일반선수  78.240  77.514295
# 2  유명선수  71.895  71.041606
# 3  유명선수  79.250  78.544623

# %%
# 특정 칼럼만 추출해서 새로운 데이터프레임 생성
selected_columns = ['name', 'position', '강화', 'max', 'min', 'only_one', '출생', '리그',
                    '생년', '생월', '생일', '키', '몸무게', '체격', '명성', '능력치',
                    '다이빙', '핸들링']

df2 = df[selected_columns]
df2
# Out:
#          name position  강화  max  min  only_one   출생   리그    생년  생월  생일    키  \
# 0         이운재       GK   1    0    1         0   한국   한국  1973   4  26  182
# 1         이운재       GK   1    1    0         0   한국   한국  1973   4  26  182
# 2         김병지       GK   1    0    1         0   한국   한국  1970   4   8  184
# 3         김병지       GK   1    1    0         0   한국   한국  1970   4   8  184
# 4         조현우       GK   1    0    1         0   한국   한국  1991   9  25  189
# ..        ...      ...  ..  ...  ...       ...  ...  ...   ...  ..  ..  ...
# 98      A. 사빈       GK   1    0    0         1  러시아  러시아  1999   8  30  193
# 99     A. 바슈틴       GK   1    1    0         0  러시아  스웨덴  1995   3   4  190
# 100    A. 바슈틴       GK   1    0    1         0  러시아  스웨덴  1995   3   4  190
# 101  A. 미트류스킨       GK   1    0    0         1  러시아  러시아  1996   2   8  189
# 102   A. 레브로프       GK   1    0    0         1  러시아  러시아  1984   3   4  193
#
#      몸무게  체격    명성  능력치  다이빙  핸들링
# 0     82  보통  유명선수   89   86   92
# 1     82  보통  유명선수  104  102  109
# 2     78  보통  유명선수   89   92   89
# 3     78  보통  유명선수   97  101   97
# 4     75  마름  일반선수   84   85   81
# ..   ...  ..   ...  ...  ...  ...
# 98    94  보통  일반선수   55   60   56
# 99    80  보통  일반선수   63   66   58
# 100   80  보통  일반선수   61   64   57
# 101   79  보통  일반선수   59   63   56
# 102   90  보통  일반선수   63   63   61
#
# [103 rows x 18 columns]

# %%
# X = df2.drop(['능력치'], axis = 1)
# y = df2['능력치']
# X = df2.drop(['다이빙'], axis = 1)
# y = df2['다이빙']
X = df2.drop(['핸들링'], axis = 1)
y = df2['핸들링']



# 데이터 셋을 셔플하지 않고 train/test로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %% [markdown]
# # Pycaret

# %%
# 분류 작업을 위한 pycaret 초기화
clf = setup(X_train, target=y_train, session_id=123)
# Out:
# <style type="text/css">
# #T_c435c_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c435c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c435c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c435c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c435c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c435c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c435c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c435c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c435c_row1_col1" class="data row1 col1" >핸들링</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c435c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c435c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c435c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c435c_row3_col1" class="data row3 col1" >(82, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c435c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c435c_row4_col1" class="data row4 col1" >(82, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c435c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c435c_row5_col1" class="data row5 col1" >(57, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c435c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c435c_row6_col1" class="data row6 col1" >(25, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c435c_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_c435c_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c435c_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_c435c_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c435c_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_c435c_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c435c_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_c435c_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c435c_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_c435c_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c435c_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_c435c_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c435c_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_c435c_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c435c_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_c435c_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c435c_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_c435c_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c435c_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_c435c_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c435c_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_c435c_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c435c_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_c435c_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c435c_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_c435c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c435c_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_c435c_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c435c_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_c435c_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c435c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c435c_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_c435c_row22_col1" class="data row22 col1" >bbac</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(n_select = 3)

# 특정 모델들만 비교 (예: LightGBM, XGBoost, Random Forest)
# best_model = compare_models(n_select = 3, include=['huber', 'dummy', 'en', 'knn', 'lasso', 'ada', 'lightgbm', 'catboost', 'lightgbm', 'xgboost'])
# Out:
# <style type="text/css">
# #T_a1062 th {
#   text-align: left;
# }
# #T_a1062_row0_col0, #T_a1062_row0_col1, #T_a1062_row0_col2, #T_a1062_row0_col3, #T_a1062_row1_col0, #T_a1062_row2_col0, #T_a1062_row2_col1, #T_a1062_row2_col2, #T_a1062_row2_col3, #T_a1062_row2_col4, #T_a1062_row2_col5, #T_a1062_row2_col6, #T_a1062_row3_col0, #T_a1062_row3_col1, #T_a1062_row3_col2, #T_a1062_row3_col3, #T_a1062_row3_col4, #T_a1062_row3_col5, #T_a1062_row3_col6, #T_a1062_row4_col0, #T_a1062_row4_col1, #T_a1062_row4_col2, #T_a1062_row4_col3, #T_a1062_row4_col4, #T_a1062_row4_col5, #T_a1062_row4_col6, #T_a1062_row5_col0, #T_a1062_row5_col1, #T_a1062_row5_col2, #T_a1062_row5_col3, #T_a1062_row5_col4, #T_a1062_row5_col5, #T_a1062_row5_col6, #T_a1062_row6_col0, #T_a1062_row6_col1, #T_a1062_row6_col2, #T_a1062_row6_col3, #T_a1062_row6_col4, #T_a1062_row6_col5, #T_a1062_row6_col6, #T_a1062_row7_col0, #T_a1062_row7_col1, #T_a1062_row7_col2, #T_a1062_row7_col3, #T_a1062_row7_col4, #T_a1062_row7_col5, #T_a1062_row7_col6, #T_a1062_row8_col0, #T_a1062_row8_col1, #T_a1062_row8_col2, #T_a1062_row8_col3, #T_a1062_row8_col4, #T_a1062_row8_col5, #T_a1062_row8_col6, #T_a1062_row9_col0, #T_a1062_row9_col1, #T_a1062_row9_col2, #T_a1062_row9_col3, #T_a1062_row9_col4, #T_a1062_row9_col5, #T_a1062_row9_col6, #T_a1062_row10_col0, #T_a1062_row10_col1, #T_a1062_row10_col2, #T_a1062_row10_col3, #T_a1062_row10_col4, #T_a1062_row10_col5, #T_a1062_row10_col6, #T_a1062_row11_col0, #T_a1062_row11_col1, #T_a1062_row11_col2, #T_a1062_row11_col3, #T_a1062_row11_col4, #T_a1062_row11_col5, #T_a1062_row11_col6, #T_a1062_row12_col0, #T_a1062_row12_col1, #T_a1062_row12_col2, #T_a1062_row12_col3, #T_a1062_row12_col4, #T_a1062_row12_col5, #T_a1062_row12_col6, #T_a1062_row13_col0, #T_a1062_row13_col1, #T_a1062_row13_col2, #T_a1062_row13_col3, #T_a1062_row13_col4, #T_a1062_row13_col5, #T_a1062_row13_col6, #T_a1062_row14_col0, #T_a1062_row14_col1, #T_a1062_row14_col2, #T_a1062_row14_col3, #T_a1062_row14_col4, #T_a1062_row14_col5, #T_a1062_row14_col6, #T_a1062_row15_col0, #T_a1062_row15_col1, #T_a1062_row15_col2, #T_a1062_row15_col3, #T_a1062_row15_col4, #T_a1062_row15_col5, #T_a1062_row15_col6, #T_a1062_row16_col0, #T_a1062_row16_col1, #T_a1062_row16_col2, #T_a1062_row16_col3, #T_a1062_row16_col4, #T_a1062_row16_col5, #T_a1062_row16_col6, #T_a1062_row17_col0, #T_a1062_row17_col1, #T_a1062_row17_col2, #T_a1062_row17_col3, #T_a1062_row17_col4, #T_a1062_row17_col5, #T_a1062_row17_col6 {
#   text-align: left;
# }
# #T_a1062_row0_col4, #T_a1062_row0_col5, #T_a1062_row0_col6, #T_a1062_row1_col1, #T_a1062_row1_col2, #T_a1062_row1_col3, #T_a1062_row1_col4, #T_a1062_row1_col5, #T_a1062_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a1062_row0_col7, #T_a1062_row1_col7, #T_a1062_row2_col7, #T_a1062_row3_col7, #T_a1062_row4_col7, #T_a1062_row5_col7, #T_a1062_row6_col7, #T_a1062_row7_col7, #T_a1062_row8_col7, #T_a1062_row10_col7, #T_a1062_row11_col7, #T_a1062_row12_col7, #T_a1062_row13_col7, #T_a1062_row14_col7, #T_a1062_row15_col7, #T_a1062_row16_col7, #T_a1062_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a1062_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a1062">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1062_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a1062_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a1062_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a1062_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a1062_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a1062_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a1062_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a1062_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1062_level0_row0" class="row_heading level0 row0" >lasso</th>
#       <td id="T_a1062_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_a1062_row0_col1" class="data row0 col1" >2.4682</td>
#       <td id="T_a1062_row0_col2" class="data row0 col2" >8.5786</td>
#       <td id="T_a1062_row0_col3" class="data row0 col3" >2.8908</td>
#       <td id="T_a1062_row0_col4" class="data row0 col4" >0.9364</td>
#       <td id="T_a1062_row0_col5" class="data row0 col5" >0.0398</td>
#       <td id="T_a1062_row0_col6" class="data row0 col6" >0.0342</td>
#       <td id="T_a1062_row0_col7" class="data row0 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_a1062_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_a1062_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_a1062_row1_col1" class="data row1 col1" >2.4675</td>
#       <td id="T_a1062_row1_col2" class="data row1 col2" >8.5740</td>
#       <td id="T_a1062_row1_col3" class="data row1 col3" >2.8902</td>
#       <td id="T_a1062_row1_col4" class="data row1 col4" >0.9364</td>
#       <td id="T_a1062_row1_col5" class="data row1 col5" >0.0398</td>
#       <td id="T_a1062_row1_col6" class="data row1 col6" >0.0342</td>
#       <td id="T_a1062_row1_col7" class="data row1 col7" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_a1062_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_a1062_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_a1062_row2_col1" class="data row2 col1" >2.5553</td>
#       <td id="T_a1062_row2_col2" class="data row2 col2" >9.4644</td>
#       <td id="T_a1062_row2_col3" class="data row2 col3" >3.0159</td>
#       <td id="T_a1062_row2_col4" class="data row2 col4" >0.9352</td>
#       <td id="T_a1062_row2_col5" class="data row2 col5" >0.0406</td>
#       <td id="T_a1062_row2_col6" class="data row2 col6" >0.0348</td>
#       <td id="T_a1062_row2_col7" class="data row2 col7" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_a1062_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_a1062_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_a1062_row3_col1" class="data row3 col1" >2.7945</td>
#       <td id="T_a1062_row3_col2" class="data row3 col2" >12.2937</td>
#       <td id="T_a1062_row3_col3" class="data row3 col3" >3.2927</td>
#       <td id="T_a1062_row3_col4" class="data row3 col4" >0.9282</td>
#       <td id="T_a1062_row3_col5" class="data row3 col5" >0.0436</td>
#       <td id="T_a1062_row3_col6" class="data row3 col6" >0.0378</td>
#       <td id="T_a1062_row3_col7" class="data row3 col7" >0.0530</td>
#     </tr>
#     <tr>
#       <th id="T_a1062_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_a1062_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_a1062_row4_col1" class="data row4 col1" >3.2653</td>
#       <td id="T_a1062_row4_col2" class="data row4 col2" >16.0763</td>
#       <td id="T_a1062_row4_col3" class="data row4 col3" >3.7832</td>
#       <td id="T_a1062_row4_col4" class="data row4 col4" >0.9102</td>
#       <td id="T_a1062_row4_col5" class="data row4 col5" >0.0486</td>
#       <td id="T_a1062_row4_col6" class="data row4 col6" >0.0425</td>
#       <td id="T_a1062_row4_col7" class="data row4 col7" >0.0650</td>
#     </tr>
#     <tr>
#       <th id="T_a1062_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_a1062_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_a1062_row5_col1" class="data row5 col1" >3.2857</td>
#       <td id="T_a1062_row5_col2" class="data row5 col2" >16.2230</td>
#       <td id="T_a1062_row5_col3" class="data row5 col3" >3.9024</td>
#       <td id="T_a1062_row5_col4" class="data row5 col4" >0.8880</td>
#       <td id="T_a1062_row5_col5" class="data row5 col5" >0.0553</td>
#       <td id="T_a1062_row5_col6" class="data row5 col6" >0.0461</td>
#       <td id="T_a1062_row5_col7" class="data row5 col7" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_a1062_level0_row6" class="row_head

# %%
b1 = best_model[0]
b2 = best_model[1]
b3 = best_model[2]

predictions_1 = predict_model(b1,data=X_test)
predictions_2 = predict_model(b2,data=X_test)
predictions_3 = predict_model(b3,data=X_test)

# %%
# b1
b2
# Out:
# LassoLars(random_state=123)

# %%
# predictions_1
predictions_2
# Out:
#           name position  강화  max  min  only_one   출생    리그    생년  생월  생일    키  \
# 30         노동건       GK   1    0    0         1   한국    한국  1991  10   4  192
# 67     E. 코보제프       GK   1    0    0         1  러시아   러시아  1990   1  11  188
# 62   이고리 아킨페예프       GK   1    1    0         0  러시아   러시아  1986   4   8  186
# 47         윤평국       GK   1    1    0         0   한국    한국  1992   2   8  189
# 42         오승훈       GK   1    1    0         0   한국    한국  1988   6  30  192
# 40         양형모       GK   1    1    0         0   한국    한국  1991   7  16  185
# 90     I. 스비노프       GK   1    0    0         1  러시아   러시아  2000   9  25  190
# 45         유상훈       GK   1    0    1         0   한국    한국  1989   5  25  194
# 10         김영광       GK   1    1    0         0   한국    한국  1983   6  28  184
# 0          이운재       GK   1    0    1         0   한국    한국  1973   4  26  182
# 18         구성윤       GK   1    1    0         0   한국    한국  1994   6  27  195
# 31         박주원       GK   1    0    0         1   한국    한국  1990  10  19  191
# 97     A. 셀리호프       GK   1    0    0         1  러시아   러시아  1994   4   7  190
# 85     S. 크리추크       GK   1    0    1         0  러시아  포르투갈  1990  12   1  192
# 76     막심 루다코프       GK   1    0    0         1  러시아   핀란드  1996   1  22  190
# 4          조현우       GK   1    0    1         0   한국    한국  1991   9  25  189
# 79        길레르미       GK   1    0    0         1  러시아   러시아  1985  12  12  198
# 33         백종범       GK   1    0    0         1   한국    한국  2001   1  21  190
# 12         최은성       GK   1    0    1         0   한국    한국  1971   4   5  184
# 26         김정훈       GK   1    0    1         0   한국    한국  2001   4  20  188
# 100     A. 바슈틴       GK   1    0    1         0  러시아   스웨덴  1995   3   4  190
#
#      몸무게  체격    명성  능력치  다이빙  prediction_label
# 30    88  보통  일반선수   87   94         88.234839
# 67    81  보통  일반선수   60   66         59.114960
# 62    78  보통  유명선수  101  105        101.167294
# 47    85  보통  일반선수   85   85         85.414495
# 42    79  보통  일반선수   87   91         86.368024
# 40    84  보통  일반선수  101  106        101.125020
# 90    81  마름  일반선수   57   59         55.296401
# 45    84  보통  일반선수   82   82         82.046341
# 10    86  보통  일반선수   94   89         93.719803
# 0     82  보통  유명선수   89   86         88.402715
# 18    82  마름  일반선수   89   91         88.932878
# 31    77  보통  일반선수   85   87         84.448285
# 97    85  보통  일반선수   64   66         63.844166
# 85    85  보통  일반선수   64   65         64.412591
# 76    79  마름  일반선수   58   61         56.395420
# 4     75  마름  일반선수   84   85         82.756432
# 79    96  마름  유명선수   70   74         71.837189
# 33    85  보통  일반선수   81   86         80.545931
# 12    82  보통  일반선수   83   84         83.378964
# 26    80  보통  일반선수   82   81         80.975443
# 100   80  보통  일반선수   61   64         60.393444

# %%
# 인덱스를 기준으로 레프트 조인 수행
# result = predictions_1.join(y_test, how='left')
result = predictions_2.join(y_test, how='left')
result
# Out:
#           name position  강화  max  min  only_one   출생    리그    생년  생월  생일    키  \
# 30         노동건       GK   1    0    0         1   한국    한국  1991  10   4  192
# 67     E. 코보제프       GK   1    0    0         1  러시아   러시아  1990   1  11  188
# 62   이고리 아킨페예프       GK   1    1    0         0  러시아   러시아  1986   4   8  186
# 47         윤평국       GK   1    1    0         0   한국    한국  1992   2   8  189
# 42         오승훈       GK   1    1    0         0   한국    한국  1988   6  30  192
# 40         양형모       GK   1    1    0         0   한국    한국  1991   7  16  185
# 90     I. 스비노프       GK   1    0    0         1  러시아   러시아  2000   9  25  190
# 45         유상훈       GK   1    0    1         0   한국    한국  1989   5  25  194
# 10         김영광       GK   1    1    0         0   한국    한국  1983   6  28  184
# 0          이운재       GK   1    0    1         0   한국    한국  1973   4  26  182
# 18         구성윤       GK   1    1    0         0   한국    한국  1994   6  27  195
# 31         박주원       GK   1    0    0         1   한국    한국  1990  10  19  191
# 97     A. 셀리호프       GK   1    0    0         1  러시아   러시아  1994   4   7  190
# 85     S. 크리추크       GK   1    0    1         0  러시아  포르투갈  1990  12   1  192
# 76     막심 루다코프       GK   1    0    0         1  러시아   핀란드  1996   1  22  190
# 4          조현우       GK   1    0    1         0   한국    한국  1991   9  25  189
# 79        길레르미       GK   1    0    0         1  러시아   러시아  1985  12  12  198
# 33         백종범       GK   1    0    0         1   한국    한국  2001   1  21  190
# 12         최은성       GK   1    0    1         0   한국    한국  1971   4   5  184
# 26         김정훈       GK   1    0    1         0   한국    한국  2001   4  20  188
# 100     A. 바슈틴       GK   1    0    1         0  러시아   스웨덴  1995   3   4  190
#
#      몸무게  체격    명성  능력치  다이빙  prediction_label  핸들링
# 30    88  보통  일반선수   87   94         88.234839   84
# 67    81  보통  일반선수   60   66         59.114960   57
# 62    78  보통  유명선수  101  105        101.167294   92
# 47    85  보통  일반선수   85   85         85.414495   89
# 42    79  보통  일반선수   87   91         86.368024   85
# 40    84  보통  일반선수  101  106        101.125020  100
# 90    81  마름  일반선수   57   59         55.296401   59
# 45    84  보통  일반선수   82   82         82.046341   83
# 10    86  보통  일반선수   94   89         93.719803   94
# 0     82  보통  유명선수   89   86         88.402715   92
# 18    82  마름  일반선수   89   91         88.932878   87
# 31    77  보통  일반선수   85   87         84.448285   87
# 97    85  보통  일반선수   64   66         63.844166   62
# 85    85  보통  일반선수   64   65         64.412591   67
# 76    79  마름  일반선수   58   61         56.395420   55
# 4     75  마름  일반선수   84   85         82.756432   81
# 79    96  마름  유명선수   70   74         71.837189   66
# 33    85  보통  일반선수   81   86         80.545931   80
# 12    82  보통  일반선수   83   84         83.378964   81
# 26    80  보통  일반선수   82   81         80.975443   83
# 100   80  보통  일반선수   61   64         60.393444   57

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(result.index, result['prediction_label'], color='red', alpha=0.5, label='Prediction Label')
plt.scatter(result.index, result['핸들링'], color='blue', alpha=0.5, label='Y')

plt.title('Prediction vs Y')
plt.xlabel('Index')
plt.ylabel('Value')

legend = plt.legend(frameon=True)
legend.get_frame().set_edgecolor('black')
legend.get_frame().set_linewidth(1.5)
    
plt.grid(True)
plt.show()

# %%
# sa1 = predict_model(b1,data=sa)
sa1 = predict_model(b2,data=sa)
sa1
# Out:
#    name position  강화  max  min  only_one   출생  리그    생년  생월  생일    키  몸무게  체격  \
# 0  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 1  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
# 2  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 3  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
#
#      명성        능력치        다이빙  prediction_label
# 0  일반선수  70.334999  69.450218         71.648570
# 1  일반선수  78.239998  77.514297         79.796873
# 2  유명선수  71.894997  71.041603         73.256582
# 3  유명선수  79.250000  78.544624         80.837962

# %%
# sa1['prediction_label'] = sa1['prediction_label'].round()
# sa1.rename(columns={'prediction_label': '능력치'}, inplace=True)
# sa1.rename(columns={'prediction_label': '다이빙'}, inplace=True)
sa1.rename(columns={'prediction_label': '핸들링'}, inplace=True)
sa1
# Out:
#    name position  강화  max  min  only_one   출생  리그    생년  생월  생일    키  몸무게  체격  \
# 0  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 1  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
# 2  사리체프       GK   1    0    1         0  러시아  한국  1960   1  12  193   87  보통
# 3  사리체프       GK   1    1    0         0  러시아  한국  1960   1  12  193   87  보통
#
#      명성        능력치        다이빙        핸들링
# 0  일반선수  70.334999  69.450218  71.648570
# 1  일반선수  78.239998  77.514297  79.796873
# 2  유명선수  71.894997  71.041603  73.256582
# 3  유명선수  79.250000  78.544624  80.837962

# %%
# sa1.to_csv('result1.csv', index=False, encoding='cp949')
# sa1.to_csv('result2.csv', index=False, encoding='cp949')
sa1.to_csv('result3.csv', index=False, encoding='cp949')
print("done")
# Out:
# done
